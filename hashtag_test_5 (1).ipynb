# %%
import pandas as pd
df = pd.read_csv("hashtag_201817.csv")
df.head()
t = []
with open("hashtag_201817.csv",encoding='utf8', errors='ignore') as f:
    mainlist=[]
    for line in f:
        temp=line.split(",")
        sublist=[]
        for word in temp:
            word=word.replace("'","")
            word=word.replace('"',"")
            word=word.replace("\n","")
            if word and word!='\n' and word.startswith("#"):
                sublist.append(word)
            if word and word.startswith("#"):
                t.append(word)
        mainlist.append(sublist)

# %%
hashtags=list(set(t))

# %%
#print(hashtags)

# %%
dictionary={}
list1=[]
for i,tag in enumerate(hashtags):
    c=0
    for w in t:
        if tag.lower()==w.lower():
            c=c+1
    if tag not in list1:
        list1.append(tag)
    dictionary[tag]=c

# %%
print(dictionary)
# Out:
# {'#Tradeshow': 6, '#artisprinters': 1, '#ClothingLine': 6, '#photography': 2, '#stampaonline': 5, '#mock': 1, '#tanks': 2, '#AnaJet': 8, '#leather': 1, '#Alpaca': 1, '#meter': 1, '#twinsprint…': 1, '#sports': 9, '#leadership': 1, '#Repost': 7, '#Improvement': 1, '#DTG...': 3, '#Schools': 1, '#TrendyTuesday': 1, '#alborjmachineryllc': 3, '#stateshirt': 1, '#giftsforher': 1, '#ultraprint': 1, '#gooeybutter': 1, '#hediditagain': 1, '#tagsforlikes': 1, '#shirtworks': 1, '#viceversa': 1, '#humorous': 1, '#costomshoes': 1, '#localbrand': 3, '#TShirts': 166, '#mewstardesigns': 6, '#designerslife…': 1, '#tshirt': 279, '#Conroe.': 3, '#DirecttoGarment': 320, '#sharknado…': 1, '#liveonlake': 1, '#poweringtheprint': 2, '#ninja': 2, '#Embroidery': 307, '#molloynursing': 1, '#💘': 1, '#flatbill': 1, '#designyourown': 125, '#conservewater': 1, '#ValentinesDay': 2, '#ep': 1, '#Screenprinting': 384, '#ISSLongBeach.': 2, '#events': 2, '#R…https://t.co/Clu9iTALMo': 1, '#mesquite': 1, '#babyclothing': 1, '#thewoodlands': 19, '#CyberMonday': 1, '#celebrity': 1, '#Elite': 1, '#stpattysday2018': 1, '#happiness': 1, '#GuaranteedAloha': 5, '#TWCP': 1, '#worldcup2018': 8, '#instahappy': 1, '#Unique': 6, '#workclothes': 1, '#T-SHIRT': 19, '#storage': 1, '#lettuce': 1, '#T-ShirtPrinting': 4, '#TBT': 5, '#sexybeast': 1, '#today': 2, '#stampadiretta': 5, '#veganrobot': 1, '#Riverview': 33, '#Clientmeeting.': 1, '#heattransferfilm': 1, '#eucalyptus': 1, '#vinylheatpress': 2, '#phhs': 2, '#RogueStar': 1, '#festivals': 1, '#BrooklynBusiness': 1, '#teamwear…': 1, '#MadeInHI': 1, '#designoftheday': 2, '#christmasparade': 1, '#quote': 5, '#ecolease': 1, '#valentinesgift': 1, '#lucky': 1, '#shoe2kill': 4, '#floralmotorcycle…': 1, '#teeshirt': 6, '#banners': 20, '#tomorrow': 1, '#learning': 4, '#awesometshirts': 1, '#epson...': 1, '#flashbackfriday': 1, '#foldingclothes': 1, '#TeachMeHowToZombie': 1, '#MondayMood': 1, '#PrintingTechnique.': 1, '#local': 11, '#womenofthebible': 3, '#screenprintinglife': 1, '#ayeimraes': 1, '#tow': 1, '#fallmonogram': 1, '#exhibition': 3, '#latenightsearlymornings': 1, '#collectorsitem': 2, '#ICYMI': 1, '#Clothes': 22, '#joker': 1, '#printmaking': 14, '#I': 4, '#dating': 1, '#giftware': 1, '#OutfitDay': 1, '#DidYouKnow?': 1, '#press': 1, '#dyslexic': 1, '#denim': 8, '#onfire': 1, '#nottingham': 1, '#thoroughthreads': 1, '#etsyseller': 5, '#walnutcreek': 1, '#lowpoly': 1, '#Catspit': 9, '#Grocery': 1, '#leggings': 1, '#MerchMonster': 1, '#FashionfloLtd': 1, '#Branded': 4, '#handlettering': 1, '#brotherdtg': 7, '#newyear': 1, '#techniques': 1, '#corneliusnc': 1, '#alexa': 3, '#workmstuff': 1, '#ISS18:': 2, '#drinkmorewine': 1, '#tee…': 1, '#Halloween2017': 2, '#redbubble': 1, '#woofwoof': 1, '#luckoftheirish': 1, '#dtg': 1552, '#PrintMakeWear': 2, '#tardis': 1, '#bensonhurst…': 1, '#flag': 1, '#DIRECTTOGARMENT': 320, '#turd': 1, '#customTees': 40, '#delicious': 1, '#president': 1, '#SureColor': 9, '#2014.': 1, '#shreveportproud': 1, '#mcr': 1, '#classes': 1, '#schoolspirit': 2, '#vacationshirt…': 1, '#expo': 1, '#Hoodies': 22, '#mickeymouse': 1, '#Ninja': 2, '#tshurt...': 1, '#noAprilFoolingHere': 1, '#DTGmachine': 2, '#Trieste': 3, '#amazondeals': 3, '#automaticpretreatmachine': 1, '#BigFrogNewBraunfels': 2, '#BIGFROGSAV': 12, '#legorobotics': 1, '#cleaninghouses': 1, '#Thanksgiving': 2, '#badtees': 1, '#ABMDesign': 6, '#wanted': 1, '#printingtshirt': 7, '#vogue': 1, '#SmilePowerDay': 2, '#scranton': 2, '#ingtonprintingco': 3, '#tshirtshop': 4, '#belgianfashionblogger': 1, '#Bag': 1, '#garmentprinting…': 1, '#StrongWomen': 1, '#SGIAExpo': 1, '#menswear': 1, '#TopicTuesday': 1, '#Printingtshirts': 1, '#APPAREL': 99, '#Hoodie': 13, '#educatortee': 1, '#RicohDTG': 2, '#HometownSwag': 1, '#stickers': 144, '#posters': 6, '#Birmingham.': 1, '#starteeapparel': 1, '#puertoricoselevanta': 1, '#Celebrant': 1, '#HappyNewYear2018': 1, '#comicbook': 1, '#Berlin': 6, '#digisign': 1, '#grafixbar': 1, '#Volunteers.': 1, '#wow': 1, '#chicago': 13, '# ...

# %%
matrix=[[0]*len(hashtags)]*len(hashtags)
m=[]

final=[]
values={}
new={}
for i,h1 in enumerate(hashtags):
    #l=[]
    li=[]
   
    
    for j,h2 in enumerate(hashtags): 
        c=0
        for sublist in mainlist:
            if h1!=h2:
                if h2 in sublist and h1 in sublist:
                    c=c+1
        #if c>1:
            #print("row",i,h1,"col",j,h2,"count=",c)
        l=[]
        #li=[]
        if c>10:        
            matrix[i][j]=c 
            final.append(h1)
            values[h1]=c
            l.append(h1)
            l.append(h2)
            l.append(c)
            tuple(l)
            li.append(h2)
            #li.append(c)
            #print(li)            
            m.append(l)
            #print(c)
        j=j+1
    i=i+1
    if li:
        
    #    m.append(l)
        new[h1]=li
        #print(new)

# %%
print(m)
# Out:
# [['#kornit', '#dtg', 11], ['#forsale', '#mens', 21], ['#forsale', '#womens', 21], ['#forsale', '#ebay', 16], ['#forsale', '#wpclothing', 21], ['#forsale', '#fashion', 15], ['#forsale', '#dtg', 21], ['#tee', '#mashup', 23], ['#tee', '#pop', 23], ['#tee', '#comics', 23], ['#tee', '#scifi', 23], ['#tee', '#anime', 23], ['#tee', '#DTG', 24], ['#etsy', '#design', 24], ['#etsy', '#Raleigh', 17], ['#etsy', '#etsyshop', 16], ['#etsy', '#fashion', 24], ['#etsy', '#dtg', 39], ['#etsy', '#apparel', 29], ['#print', '#dtg', 45], ['#heatpress', '#screenprinting', 20], ['#heatpress', '#itswhatwedo', 20], ['#heatpress', '#dtg', 23], ['#VDDesigns', '#customeverything', 17], ['#VDDesigns', '#dtg', 18], ['#tshirtprinting', '#dtg', 12], ['#mens', '#forsale', 21], ['#mens', '#womens', 25], ['#mens', '#ebay', 19], ['#mens', '#wpclothing', 25], ['#mens', '#fashion', 19], ['#mens', '#dtg', 25], ['#dtgprinting', '#tshirt', 12], ['#dtgprinting', '#dtg', 57], ['#custom', '#screenprinting', 13], ['#custom', '#design', 11], ['#custom', '#directtogarment', 14], ['#custom', '#dtg', 58], ['#anajet', '#dtg', 14], ['#screenprinting', '#heatpress', 20], ['#screenprinting', '#custom', 13], ['#screenprinting', '#design', 11], ['#screenprinting', '#directtogarment', 15], ['#screenprinting', '#embroidery', 20], ['#screenprinting', '#printing', 12], ['#screenprinting', '#tshirt', 34], ['#screenprinting', '#vinyl', 26], ['#screenprinting', '#DTG', 13], ['#screenprinting', '#itswhatwedo', 20], ['#screenprinting', '#dtg', 95], ['#rnrcustomtattoosandapparel', '#dtg', 12], ['#design', '#etsy', 24], ['#design', '#custom', 11], ['#design', '#screenprinting', 11], ['#design', '#Raleigh', 14], ['#design', '#fashion', 18], ['#design', '#dtg', 47], ['#design', '#apparel', 22], ['#directtogarment', '#custom', 14], ['#directtogarment', '#screenprinting', 15], ['#directtogarment', '#printing', 22], ['#directtogarment', '#DTG', 18], ['#directtogarment', '#dtg', 65], ['#tees', '#dtg', 21], ['#customeverything', '#VDDesigns', 17], ['#customeverything', '#dtg', 18], ['#dtgprintingâ€¦', '#dtg', 14], ['#dtgprint', '#dtg', 11], ['#ScreenPrint', '#DTG', 13], ['#mashup', '#tee', 23], ['#mashup', '#pop', 23], ['#mashup', '#comics', 23], ['#mashup', '#scifi', 23], ['#mashup', '#anime', 23], ['#mashup', '#DTG', 23], ['#smallbusiness', '#dtg', 13], ['#womens', '#forsale', 21], ['#womens', '#mens', 25], ['#womens', '#ebay', 19], ['#womens', '#wpclothing', 25], ['#womens', '#fashion', 19], ['#womens', '#dtg', 25], ['#Apparel', '#DTG', 15], ['#MintyTees', '#Custom', 14], ['#MintyTees', '#DTG', 13], ['#ebay', '#forsale', 16], ['#ebay', '#mens', 19], ['#ebay', '#womens', 19], ['#ebay', '#wpclothing', 19], ['#ebay', '#fashion', 16], ['#ebay', '#dtg', 19], ['#embroidery', '#screenprinting', 20], ['#embroidery', '#dtg', 45], ['#wpclothing', '#forsale', 21], ['#wpclothing', '#mens', 25], ['#wpclothing', '#womens', 25], ['#wpclothing', '#ebay', 19], ['#wpclothing', '#fashion', 19], ['#wpclothing', '#dtg', 25], ['#pop', '#tee', 23], ['#pop', '#mashup', 23], ['#pop', '#comics', 23], ['#pop', '#scifi', 23], ['#pop', '#anime', 23], ['#pop', '#DTG', 23], ['#comics', '#tee', 23], ['#comics', '#mashup', 23], ['#comics', '#pop', 23], ['#comics', '#scifi', 23], ['#comics', '#anime', 23], ['#comics', '#DTG', 23], ['#scifi', '#tee', 23], ['#scifi', '#mashup', 23], ['#scifi', '#pop', 23], ['#scifi', '#comics', 23], ['#scifi', '#anime', 23], ['#scifi', '#DTG', 23], ['#Raleigh', '#etsy', 17], ['#Raleigh', '#design', 14], ['#Raleigh', '#fashion', 14], ['#Raleigh', '#dtg', 23], ['#Raleigh', '#apparel', 15], ['#Printing', '#DTG', 17], ['#Tees', '#dtg', 12], ['#customtees', '#dtg', 12], ['#BigFrog', '#Embroidery', 13], ['#BigFrog', '#Custom', 13], ['#BigFrog', '#DTG', 15], ['#customtshirts', '#dtg', 14], ['#printing', '#screenprinting', 12], ['#printing', '#directtogarment', 22], ['#printing', '#tshirt', 16], ['#printing', '#DTG', 25], ['#printing', '#dtg', 63], ['#etsyshop', '#etsy', 16], ['#etsyshop', '#fashion', 11], ...

# %%
print(new)
# Out:
# {'#kornit': ['#dtg'], '#forsale': ['#mens', '#womens', '#ebay', '#wpclothing', '#fashion', '#dtg'], '#tee': ['#mashup', '#pop', '#comics', '#scifi', '#anime', '#DTG'], '#etsy': ['#design', '#Raleigh', '#etsyshop', '#fashion', '#dtg', '#apparel'], '#print': ['#dtg'], '#heatpress': ['#screenprinting', '#itswhatwedo', '#dtg'], '#VDDesigns': ['#customeverything', '#dtg'], '#tshirtprinting': ['#dtg'], '#mens': ['#forsale', '#womens', '#ebay', '#wpclothing', '#fashion', '#dtg'], '#dtgprinting': ['#tshirt', '#dtg'], '#custom': ['#screenprinting', '#design', '#directtogarment', '#dtg'], '#anajet': ['#dtg'], '#screenprinting': ['#heatpress', '#custom', '#design', '#directtogarment', '#embroidery', '#printing', '#tshirt', '#vinyl', '#DTG', '#itswhatwedo', '#dtg'], '#rnrcustomtattoosandapparel': ['#dtg'], '#design': ['#etsy', '#custom', '#screenprinting', '#Raleigh', '#fashion', '#dtg', '#apparel'], '#directtogarment': ['#custom', '#screenprinting', '#printing', '#DTG', '#dtg'], '#tees': ['#dtg'], '#customeverything': ['#VDDesigns', '#dtg'], '#dtgprintingâ€¦': ['#dtg'], '#dtgprint': ['#dtg'], '#ScreenPrint': ['#DTG'], '#mashup': ['#tee', '#pop', '#comics', '#scifi', '#anime', '#DTG'], '#smallbusiness': ['#dtg'], '#womens': ['#forsale', '#mens', '#ebay', '#wpclothing', '#fashion', '#dtg'], '#Apparel': ['#DTG'], '#MintyTees': ['#Custom', '#DTG'], '#ebay': ['#forsale', '#mens', '#womens', '#wpclothing', '#fashion', '#dtg'], '#embroidery': ['#screenprinting', '#dtg'], '#wpclothing': ['#forsale', '#mens', '#womens', '#ebay', '#fashion', '#dtg'], '#pop': ['#tee', '#mashup', '#comics', '#scifi', '#anime', '#DTG'], '#comics': ['#tee', '#mashup', '#pop', '#scifi', '#anime', '#DTG'], '#scifi': ['#tee', '#mashup', '#pop', '#comics', '#anime', '#DTG'], '#Raleigh': ['#etsy', '#design', '#fashion', '#dtg', '#apparel'], '#Printing': ['#DTG'], '#Tees': ['#dtg'], '#customtees': ['#dtg'], '#BigFrog': ['#Embroidery', '#Custom', '#DTG'], '#customtshirts': ['#dtg'], '#printing': ['#screenprinting', '#directtogarment', '#tshirt', '#DTG', '#dtg'], '#etsyshop': ['#etsy', '#fashion', '#dtg', '#apparel'], '#shirt': ['#dtg'], '#digital': ['#dtg'], '#tshirt': ['#dtgprinting', '#screenprinting', '#printing', '#vinyl', '#DTG', '#dtg'], '#Embroidery': ['#BigFrog', '#Custom', '#DTG'], '#Custom': ['#MintyTees', '#BigFrog', '#Embroidery', '#DTG'], '#vinyl': ['#screenprinting', '#tshirt', '#dtg'], '#anime': ['#tee', '#mashup', '#pop', '#comics', '#scifi', '#DTG'], '#digitalprinting': ['#dtg'], '#DTG': ['#tee', '#screenprinting', '#directtogarment', '#ScreenPrint', '#mashup', '#Apparel', '#MintyTees', '#pop', '#comics', '#scifi', '#Printing', '#BigFrog', '#printing', '#tshirt', '#Embroidery', '#Custom', '#anime'], '#customapparel': ['#dtg'], '#itswhatwedo': ['#heatpress', '#screenprinting', '#dtg'], '#tshirts': ['#dtg'], '#fashion': ['#forsale', '#etsy', '#mens', '#design', '#womens', '#ebay', '#wpclothing', '#Raleigh', '#etsyshop', '#dtg', '#apparel'], '#dtg': ['#kornit', '#forsale', '#etsy', '#print', '#heatpress', '#VDDesigns', '#tshirtprinting', '#mens', '#dtgprinting', '#custom', '#anajet', '#screenprinting', '#rnrcustomtattoosandapparel', '#design', '#directtogarment', '#tees', '#customeverything', '#dtgprintingâ€¦', '#dtgprint', '#smallbusiness', '#womens', '#ebay', '#embroidery', '#wpclothing', '#Raleigh', '#Tees', '#customtees', '#customtshirts', '#printing', '#etsyshop', '#shirt', '#digital', '#tshirt', '#vinyl', '#digitalprinting', '#customapparel', '#itswhatwedo', '#tshirts', '#fashion', '#apparel'], '#apparel': ['#etsy', '#design', '#Raleigh', '#etsyshop', '#fashion', '#dtg']}

# %%
print(values)
# Out:
# {'#kornit': 11, '#forsale': 21, '#tee': 24, '#etsy': 29, '#print': 45, '#heatpress': 23, '#VDDesigns': 18, '#tshirtprinting': 12, '#mens': 25, '#dtgprinting': 57, '#custom': 58, '#anajet': 14, '#screenprinting': 95, '#rnrcustomtattoosandapparel': 12, '#design': 22, '#directtogarment': 65, '#tees': 21, '#customeverything': 18, '#dtgprintingâ€¦': 14, '#dtgprint': 11, '#ScreenPrint': 13, '#mashup': 23, '#smallbusiness': 13, '#womens': 25, '#Apparel': 15, '#MintyTees': 13, '#ebay': 19, '#embroidery': 45, '#wpclothing': 25, '#pop': 23, '#comics': 23, '#scifi': 23, '#Raleigh': 15, '#Printing': 17, '#Tees': 12, '#customtees': 12, '#BigFrog': 15, '#customtshirts': 14, '#printing': 63, '#etsyshop': 12, '#shirt': 13, '#digital': 12, '#tshirt': 101, '#Embroidery': 21, '#Custom': 31, '#vinyl': 35, '#anime': 23, '#digitalprinting': 14, '#DTG': 23, '#customapparel': 15, '#itswhatwedo': 20, '#tshirts': 36, '#fashion': 23, '#dtg': 55, '#apparel': 55}

# %%
l2=[]
for key,value in dictionary.items():
    l1=[]
    l1.append(key)
    l1.append(value)
    l2.append(l1)
#print(l2)

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
G=nx.MultiGraph()
G.add_nodes_from(values.keys())
#adding edges
for k, v in new.items():
    G.add_edges_from(([(k, t) for t in v]))

# %%
nx.draw(G,node_size=200,with_labels=True,font_size=6, width=0.6)
plt.savefig("fig201817-edge10.png", dpi=600)
# Out:
# C:\tools\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:579: MatplotlibDeprecationWarning:
# The iterable function was deprecated in Matplotlib 3.1 and will be removed in 3.3. Use np.iterable instead.
#   if not cb.iterable(width):

# %%
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline
G=nx.Graph()

#for hashtag in hashtags:
G.add_nodes_from(final)
#nx.set_node_attributes(G, values, name=None)
G.add_weighted_edges_from(m)

# %%
nx.draw(G,with_labels=False, node_size=30, width=0.1)
plt.savefig("fig****.png", dpi=600)

# %%
'''for j in range(len(hashtags)):
    for sublist in mainlist:
        index1=hashtags.index(sublist[i])
        index2=hashtags.index(sublist[j])
        if hashtag in sublist:
            matrix[index1][index2]+=1
            matrix[index2][index1]+=1
print(matrix)'''

# %%
'''def generate_co_occurrence_matrix(corpus):
    vocab=set(corpus)
    vocab=list(corpus)
    vocab_index={word:i for i, word in enumerate(vocab)}
    bi_grams=list(bigrams(corpus))
    bigram_freq=nltk.FreqDist(bi_grams).most_common(len(bi_grams))
    co_occurrence_matrix=np.zeros((len(vocab),len(vocab)))
    for bigram in bigram_freq:
        current=bigram[0][1]
        previous=bigram[0][0]
        count=bigram[1]
        pos_current=vocab_index[current]
        pos_previous=vocab_index[previous]
        co_occurrence_matrix[pos_current][pos_previous]=count
    print(co_occurrence_matrix)
    return co_occurrence_matrix, vocab_index'''

# %%
'''data=list(itertools.chain.from_iterable(mainlist))
matrix, vocab_index=generate_co_occurrence_matrix(data)
data_matrix=pd.DataFrame(matrix, index=vocab_index, columns=vocab_index)
print(data_matrix)'''
